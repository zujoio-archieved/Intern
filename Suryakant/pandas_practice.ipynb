# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s=pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20181220', periods=6)
dates
# Out:
# DatetimeIndex(['2018-12-20', '2018-12-21', '2018-12-22', '2018-12-23',
#                '2018-12-24', '2018-12-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
 df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059
# 2018-12-24  0.362980  0.255662 -3.074080  1.948700
# 2018-12-25  0.717467  2.189939  3.291840 -1.453339

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059
# 2018-12-24  0.362980  0.255662 -3.074080  1.948700

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20181220'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2018-12-20  1.0  3   test  foo
# 1  1.0 2018-12-20  1.0  3  train  foo
# 2  1.0 2018-12-20  1.0  3   test  foo
# 3  1.0 2018-12-20  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# df2.<TAB>

# %%
df.index
# Out:
# DatetimeIndex(['2018-12-20', '2018-12-21', '2018-12-22', '2018-12-23',
#                '2018-12-24', '2018-12-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.06881332, -1.21588597, -1.1054818 , -0.68690332],
#        [-0.38317573, -0.08844241,  0.24320931, -0.52450627],
#        [-1.5280365 ,  0.0046796 ,  1.72883981, -1.33972613],
#        [ 0.08203647, -0.98278625,  1.29148867,  1.21605865],
#        [ 0.36298009,  0.25566207, -3.07407985,  1.94870011],
#        [ 0.71746739,  2.18993943,  3.29183962, -1.45333926]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.302924  0.027194  0.395969 -0.139953
# std    0.863336  1.209037  2.248711  1.400908
# min   -1.528037 -1.215886 -3.074080 -1.453339
# 25%   -0.897404 -0.759200 -0.768309 -1.176520
# 50%   -0.150570 -0.041881  0.767349 -0.605705
# 75%    0.292744  0.192916  1.619502  0.780917
# max    0.717467  2.189939  3.291840  1.948700

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2018-12-20 -0.686903 -1.105482 -1.215886 -1.068813
# 2018-12-21 -0.524506  0.243209 -0.088442 -0.383176
# 2018-12-22 -1.339726  1.728840  0.004680 -1.528037
# 2018-12-23  1.216059  1.291489 -0.982786  0.082036
# 2018-12-24  1.948700 -3.074080  0.255662  0.362980
# 2018-12-25 -1.453339  3.291840  2.189939  0.717467

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726
# 2018-12-24  0.362980  0.255662 -3.074080  1.948700
# 2018-12-25  0.717467  2.189939  3.291840 -1.453339

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2018-12-23  0.082036 -0.982786
# 2018-12-24  0.362980  0.255662

# %%
df[df.C> 0]
# Out:
#                    A         B         C         D
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059
# 2018-12-25  0.717467  2.189939  3.291840 -1.453339

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2018-12-20       NaN       NaN       NaN       NaN
# 2018-12-21       NaN       NaN  0.243209       NaN
# 2018-12-22       NaN  0.004680  1.728840       NaN
# 2018-12-23  0.082036       NaN  1.291489  1.216059
# 2018-12-24  0.362980  0.255662       NaN  1.948700
# 2018-12-25  0.717467  2.189939  3.291840       NaN

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903    one
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506    one
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726    two
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059  three
# 2018-12-24  0.362980  0.255662 -3.074080  1.948700   four
# 2018-12-25  0.717467  2.189939  3.291840 -1.453339  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B        C         D     E
# 2018-12-22 -1.528037  0.004680  1.72884 -1.339726   two
# 2018-12-24  0.362980  0.255662 -3.07408  1.948700  four

# %%
-df
# Out:
#                    A         B         C         D
# 2018-12-20  1.068813  1.215886  1.105482  0.686903
# 2018-12-21  0.383176  0.088442 -0.243209  0.524506
# 2018-12-22  1.528037 -0.004680 -1.728840  1.339726
# 2018-12-23 -0.082036  0.982786 -1.291489 -1.216059
# 2018-12-24 -0.362980 -0.255662  3.074080 -1.948700
# 2018-12-25 -0.717467 -2.189939 -3.291840  1.453339

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1
# Out:
#                    A         B         C         D   E
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903 NaN
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506 NaN
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726 NaN
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059 NaN

# %%
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df1
# Out:
#                    A         B         C         D   E
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903 NaN
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506 NaN
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726 NaN
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059 NaN

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D     E
# 2018-12-20  False  False  False  False  True
# 2018-12-21  False  False  False  False  True
# 2018-12-22  False  False  False  False  True
# 2018-12-23  False  False  False  False  True

# %%
df1.mean()
df1[0:,'A']=np.nan
# Out:
# A   -0.724497
# B   -0.570609
# C    0.539514
# D   -0.333769
# E         NaN
# dtype: float64

# %%
df1.apply(lambda x:x.max()-x.min())
# Out:
# A         1.610073
# B         1.220566
# C         2.834322
# D         2.555785
# E              NaN
# (0, A)         NaN
# dtype: float64

# %%
df1.mean()
# Out:
# A        -0.724497
# B        -0.570609
# C         0.539514
# D        -0.333769
# E              NaN
# (0, A)         NaN
# dtype: float64

# %%
df1
# Out:
#                    A         B         C         D   E  (0, A)
# 2018-12-20 -1.068813 -1.215886 -1.105482 -0.686903 NaN     NaN
# 2018-12-21 -0.383176 -0.088442  0.243209 -0.524506 NaN     NaN
# 2018-12-22 -1.528037  0.004680  1.728840 -1.339726 NaN     NaN
# 2018-12-23  0.082036 -0.982786  1.291489  1.216059 NaN     NaN

# %%
rng = pd.date_range('20/12/2018 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2018-12-20   -0.812372
# 2018-12-21    0.146997
# 2018-12-22   -1.466648
# 2018-12-23   -0.833242
# 2018-12-24    0.492647
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2018-12-20 00:00:00+00:00   -0.812372
# 2018-12-21 00:00:00+00:00    0.146997
# 2018-12-22 00:00:00+00:00   -1.466648
# 2018-12-23 00:00:00+00:00   -0.833242
# 2018-12-24 00:00:00+00:00    0.492647
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2018-12-19 19:00:00-05:00   -0.812372
# 2018-12-20 19:00:00-05:00    0.146997
# 2018-12-21 19:00:00-05:00   -1.466648
# 2018-12-22 19:00:00-05:00   -0.833242
# 2018-12-23 19:00:00-05:00    0.492647
# Freq: D, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts
# Out:
# 1990-03-01 09:00    0.340520
# 1990-06-01 09:00   -1.781356
# 1990-09-01 09:00   -1.426061
# 1990-12-01 09:00    0.858428
# 1991-03-01 09:00   -0.395515
# 1991-06-01 09:00   -1.382451
# 1991-09-01 09:00   -0.464256
# 1991-12-01 09:00   -1.706767
# 1992-03-01 09:00   -0.525201
# 1992-06-01 09:00    0.474723
# 1992-09-01 09:00    0.191712
# 1992-12-01 09:00   -0.809754
# 1993-03-01 09:00    2.612216
# 1993-06-01 09:00    0.614803
# 1993-09-01 09:00   -1.401637
# 1993-12-01 09:00    1.071346
# 1994-03-01 09:00   -0.800741
# 1994-06-01 09:00    0.914087
# 1994-09-01 09:00    0.299189
# 1994-12-01 09:00   -0.955337
# 1995-03-01 09:00    0.467872
# 1995-06-01 09:00    1.116455
# 1995-09-01 09:00    1.088004
# 1995-12-01 09:00   -0.042108
# 1996-03-01 09:00   -0.861510
# 1996-06-01 09:00   -0.209553
# 1996-09-01 09:00    0.947429
# 1996-12-01 09:00   -0.240450
# 1997-03-01 09:00   -0.558605
# 1997-06-01 09:00   -1.015355
# 1997-09-01 09:00    0.515733
# 1997-12-01 09:00   -0.286067
# 1998-03-01 09:00   -0.027701
# 1998-06-01 09:00    0.666819
# 1998-09-01 09:00    0.537936
# 1998-12-01 09:00   -0.971223
# 1999-03-01 09:00    0.305306
# 1999-06-01 09:00    0.819760
# 1999-09-01 09:00   -1.718305
# 1999-12-01 09:00   -1.000051
# 2000-03-01 09:00   -0.058017
# 2000-06-01 09:00   -1.878579
# 2000-09-01 09:00    0.117638
# 2000-12-01 09:00   -0.593537
# Freq: H, dtype: float64

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

# %%
ts
# Out:
# 2000-01-01    0.021434
# 2000-01-02    0.471760
# 2000-01-03    0.728337
# 2000-01-04    1.298997
# 2000-01-05    0.318403
# 2000-01-06    0.939926
# 2000-01-07    0.774883
# 2000-01-08    2.265177
# 2000-01-09    2.818677
# 2000-01-10    3.569290
# 2000-01-11    2.033360
# 2000-01-12    2.747710
# 2000-01-13    3.373354
# 2000-01-14    3.567369
# 2000-01-15    3.418342
# 2000-01-16    3.935841
# 2000-01-17    3.889717
# 2000-01-18    3.395159
# 2000-01-19    4.176562
# 2000-01-20    3.823947
# 2000-01-21    5.181287
# 2000-01-22    6.182707
# 2000-01-23    5.322618
# 2000-01-24    5.062970
# 2000-01-25    4.388383
# 2000-01-26    3.637101
# 2000-01-27    4.481698
# 2000-01-28    4.051645
# 2000-01-29    3.647756
# 2000-01-30    4.462816
#                 ...
# 2002-08-28    7.547937
# 2002-08-29    6.619215
# 2002-08-30    5.760104
# 2002-08-31    3.741473
# 2002-09-01    3.228916
# 2002-09-02    1.667283
# 2002-09-03    2.444348
# 2002-09-04    1.762018
# 2002-09-05    3.975673
# 2002-09-06    4.072037
# 2002-09-07    2.724787
# 2002-09-08    3.182041
# 2002-09-09    3.845065
# 2002-09-10    3.595877
# 2002-09-11    4.248344
# 2002-09-12    2.595060
# 2002-09-13    2.622979
# 2002-09-14    3.324447
# 2002-09-15    2.853354
# 2002-09-16    4.909762
# 2002-09-17    4.860527
# 2002-09-18    4.468004
# 2002-09-19    3.902970
# 2002-09-20    4.031003
# 2002-09-21    4.285106
# 2002-09-22    2.462286
# 2002-09-23    1.576940
# 2002-09-24    1.390717
# 2002-09-25    1.353444
# 2002-09-26    1.260463
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])

# %%
df=df.cumsum()

# %%
df.plot()

# %%
df.to_hdf('foo.h5','df')

# %%
pd.read_hdf('foo.h5','df')
# Out:
#                     A          B          C          D
# 2000-01-01   1.464844  -0.140466  -0.909844  -0.949674
# 2000-01-02   1.377683  -0.684801  -1.323632   0.726560
# 2000-01-03   2.743069  -1.398046   0.050337   0.643693
# 2000-01-04   3.448690  -0.179509   1.533138   0.008547
# 2000-01-05   4.211272  -0.270765   1.865539  -0.414481
# 2000-01-06   5.191162   0.250107   1.923767  -1.463932
# 2000-01-07   5.427656  -0.208095   2.007931   1.607561
# 2000-01-08   5.873131   1.415100   3.445559   3.297930
# 2000-01-09   4.575519   0.145378   4.579552   3.383216
# 2000-01-10   3.793236   0.743834   3.381107   4.659679
# 2000-01-11   3.229856   0.667677   2.261259   3.658019
